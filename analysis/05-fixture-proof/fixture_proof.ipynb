# %% [markdown]
# # Fixture-Proof Players — Playground #5
#
# Is a player a **flat-track bully** or the **real deal**? We split every player's 2025/26 returns by the *context* of each match and ask who keeps delivering regardless.
#
# Two axes of the same question (spec: [brainstorming/12](../../brainstorming/12-fixture-proof-players.md)):
# - **Opponent tier** — top-6 / middle-8 / bottom-6 by the **final league table**.
# - **Venue** — home vs away.
#
# **CS problem:** *stratified aggregation + a group-difference test*. Build a `player × bucket` **points-per-90** matrix, then compare buckets. Ranking by season mean is the naive sort; ranking by the **gradient** (bottom-tier PP90 − top-tier PP90, or home − away) is the honest one — it separates fixture-dependent hauls from fixture-proof output.
#
# **Method**
# 1. Derive the final table from match results → map each opponent to a tier.
# 2. PP90 per (player, bucket); minutes guard per bucket so small samples don't lie.
# 3. Gradient + mean PP90 → verdict; same machinery for both axes.
# 4. Heatmap + the mean-vs-gradient scatter (the money shot).

# %% [markdown]
# ## Config — edit me

# %%
SEASON = "2025-26"
BASE = f"https://raw.githubusercontent.com/vaastav/Fantasy-Premier-League/master/data/{SEASON}"
MERGED_URL   = f"{BASE}/gws/merged_gw.csv"
FIXTURES_URL = f"{BASE}/fixtures.csv"
TEAMS_URL    = f"{BASE}/teams.csv"

# Tier sizes over the final table (must sum to 20).
TOP_N, MID_N, BOT_N = 5, 9, 6

# Minutes a player must log *within a bucket* before that bucket's PP90 counts.
# 270 = roughly three full matches. Thin buckets are flagged, not silently dropped.
MIN_MINUTES_PER_BUCKET = 270

# Season-total minutes floor to even appear (drops fringe/cameo players).
MIN_TOTAL_MINUTES = 1500

# The analysis universe: top N scorers per position (by TOTAL points), set per position.
# Everything downstream — splits, heatmaps, scatter, combined — runs on this set.
TOP_PER_POS = {"GK": 4, "DEF": 10, "MID": 10, "FWD": 6}

# How many players to show in the heatmaps / leaderboards.
TOP_K = 30

# %% [markdown]
# ## Fetch

# %%
import io, urllib.request
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def read_csv(url):
    req = urllib.request.Request(url, headers={"User-Agent": "Mozilla/5.0"})
    return pd.read_csv(io.BytesIO(urllib.request.urlopen(req, timeout=60).read()))

gw       = read_csv(MERGED_URL)
fixtures = read_csv(FIXTURES_URL)
teams    = read_csv(TEAMS_URL)

team_name = dict(zip(teams["id"], teams["short_name"]))
print(f"{len(gw):,} player-GW rows | {gw['name'].nunique()} players | GWs {gw['round'].min()}–{gw['round'].max()}")
# Out:
# 29,757 player-GW rows | 841 players | GWs 1–38

# %% [markdown]
# ## Final table → opponent tiers
#
# `teams.csv` positions are a pre-season snapshot (all zeros), so we compute the real standings from finished match results, then slice top-6 / middle-8 / bottom-6.

# %%
fin = fixtures[(fixtures["finished"] == True) & fixtures["team_h_score"].notna()].copy()

rows = []
for _, f in fin.iterrows():
    hs, as_ = int(f["team_h_score"]), int(f["team_a_score"])
    hp, ap = (3, 0) if hs > as_ else (0, 3) if hs < as_ else (1, 1)
    rows.append((f["team_h"], hp, hs - as_))
    rows.append((f["team_a"], ap, as_ - hs))

standings = (pd.DataFrame(rows, columns=["team", "pts", "gd"])
             .groupby("team").agg(pts=("pts", "sum"), gd=("gd", "sum"))
             .sort_values(["pts", "gd"], ascending=False).reset_index())
standings["position"] = np.arange(1, len(standings) + 1)
standings["short"] = standings["team"].map(team_name)

def tier_of(pos):
    if pos <= TOP_N: return "top"
    if pos <= TOP_N + MID_N: return "mid"
    return "bot"
standings["tier"] = standings["position"].map(tier_of)
opp_tier = dict(zip(standings["team"], standings["tier"]))

print(standings[["position", "short", "pts", "gd", "tier"]].to_string(index=False))
# Out:
#  position short  pts  gd tier
#         1   ARS   85  44  top
#         2   MCI   78  42  top
#         3   MUN   71  19  top
#         4   AVL   65   7  top
#         5   LIV   60  10  top
#         6   BOU   57   4  mid
#         7   SUN   54  -6  mid
#         8   BHA   53   6  mid
#         9   BRE   53   3  mid
#        10   CHE   52   6  mid
#        11   FUL   52  -4  mid
#        12   NEW   49  -2  mid
#        13   EVE   49  -3  mid
#        14   LEE   47  -7  mid
#        15   CRY   45 -10  bot
#        16   NFO   44  -3  bot
#        17   TOT   41  -9  bot
#        18   WHU   39 -19  bot
#        19   BUR   22 -37  bot
#        20   WOL   20 -41  bot

# %% [markdown]
# ## The PP90-by-bucket engine
#
# One helper does both axes: group by `(name, bucket)`, sum points and minutes, divide to points-per-90. A bucket with fewer than `MIN_MINUTES_PER_BUCKET` is set to `NaN` (flagged, not counted).

# %%
df = gw.copy()
df["opp_tier"] = df["opponent_team"].map(opp_tier)
df["venue"] = np.where(df["was_home"], "home", "away")

# meta per player (position/team/season minutes) for filtering + labels
meta = (df.groupby("name")
          .agg(position=("position", "first"), team=("team", "first"),
               tot_min=("minutes", "sum"), tot_pts=("total_points", "sum"))
          .reset_index())
meta["pp90"] = meta["tot_pts"] / meta["tot_min"] * 90

# Universe = the top-N scorers per position by TOTAL points, where N varies by position
# (see TOP_PER_POS). A minutes floor first stops a high-per-90 cameo sneaking in.
ranked = meta[meta["tot_min"] >= MIN_TOTAL_MINUTES].sort_values("tot_pts", ascending=False)
within_cap = ranked.groupby("position").cumcount() < ranked["position"].map(TOP_PER_POS).fillna(0)
top_by_pos = ranked[within_cap]
eligible = set(top_by_pos["name"])
print(f"universe: {len(eligible)} players — top-per-position {TOP_PER_POS}")
print(top_by_pos["position"].value_counts().to_dict())

def pp90_matrix(bucket_col, order):
    """Return a player × bucket PP90 frame + parallel minutes frame (for flags)."""
    g = (df[df["name"].isin(eligible)]
         .groupby(["name", bucket_col])
         .agg(pts=("total_points", "sum"), mins=("minutes", "sum")).reset_index())
    pts = g.pivot(index="name", columns=bucket_col, values="pts").reindex(columns=order)
    mins = g.pivot(index="name", columns=bucket_col, values="mins").reindex(columns=order)
    pp90 = (pts / mins * 90).where(mins >= MIN_MINUTES_PER_BUCKET)
    return pp90, mins
# Out:
# universe: 30 players — top-per-position {'GK': 4, 'DEF': 10, 'MID': 10, 'FWD': 6}
# {'MID': 10, 'DEF': 10, 'FWD': 6, 'GK': 4}

# %% [markdown]
# ## Axis A — opponent tier
#
# **Gradient = PP90(bottom-6) − PP90(top-6).** High mean + flat gradient = *fixture-proof*. High mean + steep positive gradient = flat-track bully (only turns up against weak teams).

# %%
tier_order = ["top", "mid", "bot"]
pp90_tier, mins_tier = pp90_matrix("opp_tier", tier_order)

tierA = pp90_tier.join(meta.set_index("name")[["position", "team", "pp90"]])
tierA = tierA.rename(columns={"top": "vs_top", "mid": "vs_mid", "bot": "vs_bot", "pp90": "mean_pp90"})
tierA["gradient"] = tierA["vs_bot"] - tierA["vs_top"]

def verdict(row, g_col="gradient", flat=1.0):
    if pd.isna(row[g_col]): return "thin sample"
    if abs(row[g_col]) <= flat: return "fixture-proof"
    return "flat-track bully" if row[g_col] > 0 else "steps up"
tierA["verdict"] = tierA.apply(verdict, axis=1)

show = (tierA.sort_values(["position", "mean_pp90"], ascending=[False, False]).head(TOP_K)
        [["position", "vs_top", "vs_mid", "vs_bot", "gradient", "mean_pp90", "verdict"]]
        .round(2))
show
# Out:
#                                  position  vs_top  vs_mid  vs_bot  gradient  \
# name
# Bruno Borges Fernandes                MID    5.78    6.14    8.81      3.03
# Carlos Henrique Casimiro              MID    3.37    7.47    5.05      1.68
# Antoine Semenyo                       MID    4.17    6.43    5.81      1.64
# Harry Wilson                          MID    3.38    5.10    8.42      5.04
# Morgan Gibbs-White                    MID    5.15    5.25    6.07      0.93
# Declan Rice                           MID    3.62    5.45    6.39      2.78
# Elliot Anderson                       MID    6.30    4.60    3.90     -2.40
# Morgan Rogers                         MID    5.22    4.32    4.79     -0.43
# Dominik Szoboszlai                    MID    6.62    4.08    3.45     -3.17
# James Garner                          MID    4.00    3.64    5.08      1.08
# David Raya Martín                      GK    3.25    4.61    4.82      1.57
# Robin Roefs                            GK    2.70    3.62    5.17      2.47
# Caoimhín Kelleher                      GK    4.30    3.56    3.91     -0.39
# Jordan Pickford                        GK    3.60    3.44    3.67      0.07
# Erling Haaland                        FWD    7.05    6.99    7.91      0.86
# João Pedro Junqueira de Jesus         FWD    5.21    4.60    8.37      3.16
# Ollie Watkins                         FWD    6.32    5.29    4.59     -1.73
# Igor Thiago Nascimento Rodrigues      FWD    3.53    5.97    4.75      1.22
# Jarrod Bowen                          FWD    4.00    5.49    4.90      0.90
# Dominic Calvert-Lewin                 FWD    3.64    4.63    5.44      1.80
# Gabriel dos Santos Magalhães          DEF    4.68    7.46    7.47      2.80
# Nico O'Reilly                         DEF    5.54    6.36    3.67     -1.87
# Marc Guéhi                            DEF    4.62    5.44    5.00      0.38
# Nordi Mukiele                         DEF    3.10    3.51    8.26      5.16
# Matheus Nunes                         DEF    5.78    4.03    5.86      0.08
# Marcos Senesi Barón                   DEF    2.30    4.82    6.83      4.53
# Virgil van Dijk                       DEF    4.75    4.83    4.17     -0.58
# James Tarkowski                       DEF    3.89    3.69    6.33      2.44
# Maxence Lacroix                       DEF    4.65    4.02    5.38      0.73
# Adrien Truffert                       DEF    2.06    4.99    5.50      3.44
#
#                                   mean_pp90           verdict
# name
# Bruno Borges Fernandes                 6.90  flat-track bully
# Carlos Henrique Casimiro               5.77  flat-track bully
# Antoine Semenyo                        5.68  flat-track bully
# Harry Wilson                           5.65  flat-track bully
# Morgan Gibbs-White                     5.46     fixture-proof
# Declan Rice                            5.35  flat-track bully
# Elliot Anderson                        4.86          steps up
# Morgan Rogers                          4.64     fixture-proof
# Dominik Szoboszlai                     4.46          steps up
# James Garner                           4.19  flat-track bully
# David Raya Martín                      4.38  flat-track bully
# Robin Roefs                            3.89  flat-track bully
# Caoimhín Kelleher                      3.86     fixture-proof
# Jordan Pickford                        3.55     fixture-proof
# Erling Haaland                         7.28     fixture-proof
# João Pedro Junqueira de Jesus          5.99  flat-track bully
# Ollie Watkins                          5.31          steps up
# Igor Thiago Nascimento Rodrigues       4.96  flat-track bully
# Jarrod Bowen                           4.94     fixture-proof
# Dominic Calvert-Lewin                  4.70  flat-track bully
# Gabriel dos Santos Magalhães           6.84  flat-track bully
# Nico O'Reilly                          5.45          steps up
# Marc Guéhi                             5.11     fixture-proof
# Nordi Mukiele                          4.88  flat-track bully
# Matheus Nunes                          4.84     fixture-proof
# Marcos Senesi Barón                    4.79  flat-track bully
# Virgil van Dijk                        4.61     fixture-proof
# James Tarkowski                        4.59  flat-track bully
# Maxence Lacroix                        4.49     fixture-proof
# Adrien Truffert                        4.40  flat-track bully

# %% [markdown]
# ### Heatmap — PP90 by opponent tier (top players by mean)

# %%
def heatmap(mat, cols, collabels, title):
    top = mat.sort_values("mean_pp90", ascending=False).head(TOP_K)
    M = top[cols].values.astype(float)
    fig, ax = plt.subplots(figsize=(6, 0.42 * len(top) + 1.5))
    im = ax.imshow(M, aspect="auto", cmap="YlOrRd")
    ax.set_xticks(range(len(cols))); ax.set_xticklabels(collabels)
    ax.set_yticks(range(len(top))); ax.set_yticklabels(top.index, fontsize=8)
    for i in range(M.shape[0]):
        for j in range(M.shape[1]):
            v = M[i, j]
            ax.text(j, i, "–" if np.isnan(v) else f"{v:.1f}", ha="center", va="center", fontsize=7)
    ax.set_title(title); fig.colorbar(im, ax=ax, label="points per 90", shrink=0.6)
    plt.tight_layout(); plt.show()

heatmap(tierA, ["vs_top", "vs_mid", "vs_bot"], ["vs Top6", "vs Mid8", "vs Bot6"],
        "PP90 by opponent tier")

# %% [markdown]
# ### Money shot — mean PP90 vs tier gradient
#
# **Top-left** (high mean, gradient ≈ 0) is the fixture-proof elite. **Top-right** is high output that leans on easy fixtures.

# %%
def scatter(mat, title, xlab="mean PP90", ylab="gradient (bot − top)"):
    d = mat.dropna(subset=["gradient", "mean_pp90"])
    d = d.sort_values("mean_pp90", ascending=False).head(40)
    fig, ax = plt.subplots(figsize=(8, 6))
    ax.scatter(d["mean_pp90"], d["gradient"], s=30, alpha=0.7)
    ax.axhline(0, color="grey", lw=0.8)
    for name, r in d.iterrows():
        ax.annotate(name, (r["mean_pp90"], r["gradient"]), fontsize=7,
                    xytext=(3, 2), textcoords="offset points")
    ax.set_xlabel(xlab); ax.set_ylabel(ylab); ax.set_title(title)
    plt.tight_layout(); plt.show()

scatter(tierA, "Fixture dependence — mean PP90 vs tier gradient")

# %% [markdown]
# ## Axis B — venue (home / away)
#
# Same engine, bucket = venue. **Gradient = PP90(home) − PP90(away).** Flat ≈ venue-proof; large positive = away-day no-show.

# %%
venue_order = ["home", "away"]
pp90_venue, mins_venue = pp90_matrix("venue", venue_order)

venueB = pp90_venue.join(meta.set_index("name")[["position", "team", "pp90"]])
venueB = venueB.rename(columns={"pp90": "mean_pp90"})
venueB["gradient"] = venueB["home"] - venueB["away"]
venueB["verdict"] = venueB.apply(lambda r: verdict(r, flat=1.0), axis=1)

venueB.sort_values(["position", "mean_pp90"], ascending=[False, False]).head(TOP_K)[
    ["position", "home", "away", "gradient", "mean_pp90", "verdict"]].round(2)
# Out:
#                                  position  home  away  gradient  mean_pp90  \
# name
# Bruno Borges Fernandes                MID  7.31  6.49      0.82       6.90
# Carlos Henrique Casimiro              MID  6.58  4.70      1.88       5.77
# Antoine Semenyo                       MID  6.94  4.45      2.48       5.68
# Harry Wilson                          MID  6.60  4.69      1.90       5.65
# Morgan Gibbs-White                    MID  5.11  5.80     -0.69       5.46
# Declan Rice                           MID  4.68  5.97     -1.29       5.35
# Elliot Anderson                       MID  4.75  4.97     -0.22       4.86
# Morgan Rogers                         MID  4.36  4.93     -0.56       4.64
# Dominik Szoboszlai                    MID  3.91  5.00     -1.09       4.46
# James Garner                          MID  4.05  4.33     -0.28       4.19
# David Raya Martín                      GK  4.58  4.17      0.41       4.38
# Robin Roefs                            GK  4.39  3.35      1.04       3.89
# Caoimhín Kelleher                      GK  3.89  3.83      0.06       3.86
# Jordan Pickford                        GK  3.58  3.53      0.05       3.55
# Erling Haaland                        FWD  7.84  6.80      1.05       7.28
# João Pedro Junqueira de Jesus         FWD  5.89  6.09     -0.20       5.99
# Ollie Watkins                         FWD  5.34  5.28      0.06       5.31
# Igor Thiago Nascimento Rodrigues      FWD  5.70  4.21      1.49       4.96
# Jarrod Bowen                          FWD  5.53  4.35      1.18       4.94
# Dominic Calvert-Lewin                 FWD  4.56  4.85     -0.29       4.70
# Gabriel dos Santos Magalhães          DEF  7.04  6.65      0.40       6.84
# Nico O'Reilly                         DEF  7.48  3.59      3.90       5.45
# Marc Guéhi                            DEF  4.24  5.94     -1.71       5.11
# Nordi Mukiele                         DEF  5.93  3.76      2.17       4.88
# Matheus Nunes                         DEF  5.50  4.25      1.25       4.84
# Marcos Senesi Barón                   DEF  5.30  4.32      0.99       4.79
# Virgil van Dijk                       DEF  4.00  5.21     -1.21       4.61
# James Tarkowski                       DEF  4.21  5.00     -0.79       4.59
# Maxence Lacroix                       DEF  4.35  4.63     -0.28       4.49
# Adrien Truffert                       DEF  4.42  4.37      0.05       4.40
#
#                                            verdict
# name
# Bruno Borges Fernandes               fixture-proof
# Carlos Henrique Casimiro          flat-track bully
# Antoine Semenyo                   flat-track bully
# Harry Wilson                      flat-track bully
# Morgan Gibbs-White                   fixture-proof
# Declan Rice                               steps up
# Elliot Anderson                      fixture-proof
# Morgan Rogers                        fixture-proof
# Dominik Szoboszlai                        steps up
# James Garner                         fixture-proof
# David Raya Martín                    fixture-proof
# Robin Roefs                       flat-track bully
# Caoimhín Kelleher                    fixture-proof
# Jordan Pickford                      fixture-proof
# Erling Haaland                    flat-track bully
# João Pedro Junqueira de Jesus        fixture-proof
# Ollie Watkins                        fixture-proof
# Igor Thiago Nascimento Rodrigues  flat-track bully
# Jarrod Bowen                      flat-track bully
# Dominic Calvert-Lewin                fixture-proof
# Gabriel dos Santos Magalhães         fixture-proof
# Nico O'Reilly                     flat-track bully
# Marc Guéhi                                steps up
# Nordi Mukiele                     flat-track bully
# Matheus Nunes                     flat-track bully
# Marcos Senesi Barón                  fixture-proof
# Virgil van Dijk                           steps up
# James Tarkowski                      fixture-proof
# Maxence Lacroix                      fixture-proof
# Adrien Truffert                      fixture-proof

# %%
heatmap(venueB, ["home", "away"], ["Home", "Away"], "PP90 by venue")
scatter(venueB, "Venue dependence — mean PP90 vs home−away gradient",
        ylab="gradient (home − away)")

# %% [markdown]
# ## Combined verdict — the master table
#
# The whole universe in one place: **total points** (output) alongside **mean PP90** (rate) and both gradients (how those points were earned). Flat on **both** axes = the true set-and-forget asset; steep on both = the classic home-vs-weak flat-track bully. Ranked by mean PP90.

# %%
combined = (top_by_pos.set_index("name")[["position", "team", "tot_pts", "tot_min", "pp90"]]
            .rename(columns={"pp90": "mean_pp90"})
            .join(tierA["gradient"].rename("tier_grad"))
            .join(venueB["gradient"].rename("venue_grad")))
combined = combined.dropna(subset=["tier_grad", "venue_grad"])

def combined_label(r, flat=1.0):
    ft = abs(r["tier_grad"]) <= flat
    fv = abs(r["venue_grad"]) <= flat
    if ft and fv: return "set-and-forget (proof on both)"
    if not ft and r["tier_grad"] > 0 and r["venue_grad"] > 0: return "flat-track bully"
    if ft: return "fixture-proof only"
    if fv: return "venue-proof only"
    return "context-dependent"
combined["label"] = combined.apply(combined_label, axis=1)

# Master table for the whole piece: total output (tot_pts) + rate (mean_pp90) +
# how those points were earned (both gradients) + the verdict, ranked by rate.
combined.sort_values(["team", "mean_pp90"], ascending=[True, False])[
    ["position", "team", "tot_pts", "tot_min", "mean_pp90", "tier_grad", "venue_grad", "label"]].round(2)
# Out:
#                                  position            team  tot_pts  tot_min  \
# name
# Gabriel dos Santos Magalhães          DEF         Arsenal      209     2750
# Declan Rice                           MID         Arsenal      184     3093
# David Raya Martín                      GK         Arsenal      162     3330
# Ollie Watkins                         FWD     Aston Villa      167     2833
# Morgan Rogers                         MID     Aston Villa      169     3280
# Antoine Semenyo                       MID     Bournemouth      202     3200
# Marcos Senesi Barón                   DEF     Bournemouth      175     3288
# Adrien Truffert                       DEF     Bournemouth      165     3378
# Igor Thiago Nascimento Rodrigues      FWD       Brentford      181     3282
# Caoimhín Kelleher                      GK       Brentford      143     3330
# João Pedro Junqueira de Jesus         FWD         Chelsea      177     2658
# Marc Guéhi                            DEF  Crystal Palace      179     3150
# Maxence Lacroix                       DEF  Crystal Palace      154     3085
# James Tarkowski                       DEF         Everton      170     3330
# James Garner                          MID         Everton      159     3413
# Jordan Pickford                        GK         Everton      135     3420
# Harry Wilson                          MID          Fulham      168     2674
# Dominic Calvert-Lewin                 FWD           Leeds      142     2721
# Virgil van Dijk                       DEF       Liverpool      175     3420
# Dominik Szoboszlai                    MID       Liverpool      160     3232
# Erling Haaland                        FWD        Man City      239     2953
# Nico O'Reilly                         DEF        Man City      160     2643
# Matheus Nunes                         DEF        Man City      154     2861
# Bruno Borges Fernandes                MID         Man Utd      235     3065
# Carlos Henrique Casimiro              MID         Man Utd      165     2575
# Morgan Gibbs-White                    MID   Nott'm Forest      188     3101
# Elliot Anderson                       MID   Nott'm Forest      180     3332
# Nordi Mukiele                         DEF      Sunderland      151     2784
# Robin Roefs                            GK      Sunderland      136     3150
# Jarrod Bowen                          FWD        West Ham      187     3406
#
#                                   mean_pp90  tier_grad  venue_grad  \
# name
# Gabriel dos Santos Magalhães           6.84       2.80        0.40
# Declan Rice                            5.35       2.78       -1.29
# David Raya Martín                      4.38       1.57        0.41
# Ollie Watkins                          5.31      -1.73        0.06
# Morgan Rogers                          4.64      -0.43       -0.56
# Antoine Semenyo                        5.68       1.64        2.48
# Marcos Senesi Barón                    4.79       4.53        0.99
# Adrien Truffert                        4.40       3.44        0.05
# Igor Thiago Nascimento Rodrigues       4.96       1.22        1.49
# Caoimhín Kelleher                      3.86      -0.39        0.06
# João Pedro Junqueira de Jesus          5.99       3.16       -0.20
# Marc Guéhi                             5.11       0.38       -1.71
# Maxence Lacroix                        4.49       0.73       -0.28
# James Tarkowski                        4.59       2.44       -0.79
# James Garner                           4.19       1.08       -0.28
# Jordan Pickford                        3.55       0.07        0.05
# Harry Wilson                           5.65       5.04        1.90
# Dominic Calvert-Lewin                  4.70       1.80       -0.29
# Virgil van Dijk                        4.61      -0.58       -1.21
# Dominik Szoboszlai                     4.46      -3.17       -1.09
# Erling Haaland                         7.28       0.86        1.05
# Nico O'Reilly                          5.45      -1.87        3.90
# Matheus Nunes                          4.84       0.08        1.25
# Bruno Borges Fernandes                 6.90       3.03        0.82
# Carlos Henrique Casimiro               5.77       1.68        1.88
# Morgan Gibbs-White                     5.46       0.93       -0.69
# Elliot Anderson                        4.86      -2.40       -0.22
# Nordi Mukiele                          4.88       5.16        2.17
# Robin Roefs                            3.89       2.47        1.04
# Jarrod Bowen                           4.94       0.90        1.18
#
#                                                            label
# name
# Gabriel dos Santos Magalhães                    flat-track bully
# Declan Rice                                    context-dependent
# David Raya Martín                               flat-track bully
# Ollie Watkins                                   venue-proof only
# Morgan Rogers                     set-and-forget (proof on both)
# Antoine Semenyo                                 flat-track bully
# Marcos Senesi Barón                             flat-track bully
# Adrien Truffert                                 flat-track bully
# Igor Thiago Nascimento Rodrigues                flat-track bully
# Caoimhín Kelleher                 set-and-forget (proof on both)
# João Pedro Junqueira de Jesus                   venue-proof only
# Marc Guéhi                                    fixture-proof only
# Maxence Lacroix                   set-and-forget (proof on both)
# James Tarkowski                                 venue-proof only
# James Garner                                    venue-proof only
# Jordan Pickford                   set-and-forget (proof on both)
# Harry Wilson                                    flat-track bully
# Dominic Calvert-Lewin                           venue-proof only
# Virgil van Dijk                               fixture-proof only
# Dominik Szoboszlai                             context-dependent
# Erling Haaland                                fixture-proof only
# Nico O'Reilly                                  context-dependent
# Matheus Nunes                                 fixture-proof only
# Bruno Borges Fernandes                          flat-track bully
# Carlos Henrique Casimiro                        flat-track bully
# Morgan Gibbs-White                set-and-forget (proof on both)
# Elliot Anderson                                 venue-proof only
# Nordi Mukiele                                   flat-track bully
# Robin Roefs                                     flat-track bully
# Jarrod Bowen                                  fixture-proof only
